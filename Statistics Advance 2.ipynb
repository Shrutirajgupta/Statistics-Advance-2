# %% [markdown]
# #Theoretical Questions

# %% [markdown]
# 1. What is hypothesis testing in statistics?
#
#  Hypothesis testing is a statistical method used to determine whether there is enough evidence in a sample to infer that a certain condition is true for the entire population.
#
#
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
#  The null hypothesis (H₀) states that there is no effect or difference in the population. It is the default assumption.
#
#  The alternative hypothesis (H₁ or Ha) contradicts the null hypothesis and suggests that there is an effect or difference.
#
#
#
# 3. What is the significance level in hypothesis testing, and why is it important?
#
#  The significance level (α) is the probability of rejecting the null hypothesis when it is actually true. It is typically set at 0.05 (5%) and determines the threshold for statistical significance.
#
#
# 4. What does a P-value represent in hypothesis testing?
#
#  The P-value is the probability of obtaining test results at least as extreme as the observed results, assuming that the null hypothesis is true.
#
#
# 5. How do you interpret the P-value in hypothesis testing?
#
#  If P ≤ α, reject the null hypothesis (statistically significant).
#
#  If P > α, fail to reject the null hypothesis (not statistically significant).
#
# 6. What are Type 1 and Type 2 errors in hypothesis testing?
#
#  Type 1 error (α): Rejecting a true null hypothesis (false positive).
#
#  Type 2 error (β): Failing to reject a false null hypothesis (false negative).
#
#
#
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#
#  A one-tailed test checks for an effect in one direction only (greater than or less than).
#
#  A two-tailed test checks for an effect in both directions.
#
#
#
# 8. What is the Z-test, and when is it used in hypothesis testing?
#
#  A Z-test is used when the sample size is large (n > 30) and the population variance is known.
#
#
# 9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
#
#  It represents how many standard deviations the sample mean is from the population mean.
#
#
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
#
#  The T-distribution is used when the sample size is small (n < 30) and the population variance is unknown.
#
#
# 11. What is the difference between a Z-test and a T-test?
#
#  A Z-test is used when population variance is known, while a T-test is used when it is unknown.
#
#
# 12. What is the T-test, and how is it used in hypothesis testing?
#
#  A T-test compares the means of two groups to determine if they are significantly different.
#
#
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
#
#  Both tests compare means, but T-tests are used for smaller samples and unknown variances.
#
#
# 14. What is a confidence interval, and how is it used to interpret statistical results?
#
#  A confidence interval gives a range within which the true population parameter is expected to lie with a certain confidence level (e.g., 95%).
#
#
# 15. What is the margin of error, and how does it affect the confidence interval?
#
#  The margin of error represents the amount of error allowed in the estimate and affects the width of the confidence interval.
#
#
# 16. How is Bayes' Theorem used in statistics, and what is its significance?
#
#  Bayes' Theorem calculates conditional probabilities and is widely used in machine learning and Bayesian statistics.
#
#
# 17. What is the Chi-square distribution, and when is it used?
#
#  The Chi-square distribution is used for categorical data analysis, including goodness-of-fit and independence tests.
#
#
# 18. What is the Chi-square goodness-of-fit test, and how is it applied?
#
#  It tests whether a sample distribution matches an expected distribution.
#
#
# 19. What is the F-distribution, and when is it used in hypothesis testing?
#
#  The F-distribution is used in variance comparison tests, such as ANOVA.
#
#
# 20. What is an ANOVA test, and what are its assumptions?
#
#  ANOVA (Analysis of Variance) compares means among multiple groups. Assumptions include normality, independence, and equal variance.
#
# 21. What are the different types of ANOVA tests?
#
#
#  One-way ANOVA (one independent variable).
#
#  Two-way ANOVA (two independent variables).
#
#  Repeated measures ANOVA (same subjects measured multiple times).
#
#
#
# 22. What is the F-test, and how does it relate to hypothesis testing?
#
#  The F-test compares variances to check if they are significantly different.

# %% [markdown]
# #Practical Questions

# %% [markdown]
# 1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and
# interpret the results.

# %%
import numpy as np
from statsmodels.stats.weightstats import ztest

# Sample data
sample = np.random.normal(loc=50, scale=10, size=30)
pop_mean = 50

# Perform Z-test
z_stat, p_value = ztest(sample, value=pop_mean)

print(f"Z-statistic: {z_stat}, P-value: {p_value}")
# Out:
# Z-statistic: -1.1367558085438396, P-value: 0.25564038186596505

# %% [markdown]
# 2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

# %%
import scipy.stats as stats

data = np.random.normal(50, 10, 30)
t_stat, p_value = stats.ttest_1samp(data, 50)

print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: 0.7439177833852856, P-value: 0.462911600028837

# %% [markdown]
# 3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean.

# %%
z_stat, p_value = ztest(data, value=50)
print(f"Z-statistic: {z_stat}, P-value: {p_value}")
# Out:
# Z-statistic: 0.7439177833852856, P-value: 0.45692621605997785

# %% [markdown]
# 4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

# %%
import matplotlib.pyplot as plt

x = np.linspace(-4, 4, 100)
y = stats.norm.pdf(x)
plt.plot(x, y)
plt.axvline(x=z_stat, color='r', linestyle='--')
plt.title("Two-Tailed Z-Test Decision Region")
plt.show()

# %% [markdown]
# 5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

# %%
import seaborn as sns

sns.histplot(data, kde=True)
plt.axvline(x=50, color='r', linestyle='--')
plt.title("Type 1 and Type 2 Errors")
plt.show()

# %% [markdown]
# 6. Write a Python program to perform an independent T-test and interpret the results.

# %%
sample1 = np.random.normal(50, 10, 30)
sample2 = np.random.normal(52, 10, 30)

t_stat, p_value = stats.ttest_ind(sample1, sample2)
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: -1.5428841737449874, P-value: 0.1282978329565719

# %% [markdown]
# 7. Perform a paired sample T-test using Python and visualize the comparison results.

# %%
before = np.random.normal(50, 10, 30)
after = before + np.random.normal(0, 5, 30)

t_stat, p_value = stats.ttest_rel(before, after)
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: -0.7508794450815611, P-value: 0.45877521959309275

# %% [markdown]
# 8. Simulate data and perform both Z-test and T-test, then compare the results using Python.

# %%
import numpy as np
import scipy.stats as stats

# Function to check ANOVA assumptions
def check_anova_assumptions(groups):
    # Check Normality for each group
    print("Checking Normality using Shapiro-Wilk Test:")
    for i, group in enumerate(groups):
        stat, p = stats.shapiro(group)
        print(f"Group {i+1}: W-statistic = {stat:.4f}, P-value = {p:.4f}")
        if p < 0.05:
            print(f"  -> Group {i+1} is NOT normally distributed.")
        else:
            print(f"  -> Group {i+1} is normally distributed.")

    # Check Homogeneity of Variance (Levene's Test)
    stat, p = stats.levene(*groups)
    print("\nChecking Homogeneity of Variance (Levene’s Test):")
    print(f"Levene’s Test Statistic = {stat:.4f}, P-value = {p:.4f}")
    if p < 0.05:
        print("  -> Variances are NOT equal across groups.")
    else:
        print("  -> Variances are equal across groups.")

# %% [markdown]
# 9.  Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

# %% [markdown]
# 10. Write a Python program to calculate the margin of error for a given confidence level using sample data.

# %%
import scipy.stats as stats
import numpy as np

def margin_of_error(data, confidence=0.95):
    n = len(data)
    std_err = np.std(data, ddof=1) / np.sqrt(n)
    z_critical = stats.norm.ppf((1 + confidence) / 2)
    return z_critical * std_err

data = np.random.normal(50, 10, 30)
moe = margin_of_error(data)
print(f"Margin of Error: {moe}")
# Out:
# Margin of Error: 3.6445594750433696

# %% [markdown]
# 11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.

# %%
def bayes_theorem(prior_A, prob_B_given_A, prob_B_given_not_A):
    prob_not_A = 1 - prior_A
    prob_B = (prob_B_given_A * prior_A) + (prob_B_given_not_A * prob_not_A)
    posterior_A = (prob_B_given_A * prior_A) / prob_B
    return posterior_A

prior_A = 0.01  # Prior probability (e.g., having a disease)
prob_B_given_A = 0.95  # Sensitivity (True Positive Rate)
prob_B_given_not_A = 0.05  # False Positive Rate

posterior_A = bayes_theorem(prior_A, prob_B_given_A, prob_B_given_not_A)
print(f"Updated Probability: {posterior_A}")
# Out:
# Updated Probability: 0.16101694915254236

# %% [markdown]
# 12. D Perform a Chi-square test for independence between two categorical variables in Python.

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Sample categorical data
data = np.array([[50, 30], [20, 40]])
chi2, p, dof, expected = chi2_contingency(data)

print(f"Chi-Square Statistic: {chi2}, P-value: {p}")
# Out:
# Chi-Square Statistic: 10.529166666666667, P-value: 0.0011750518530845063

# %% [markdown]
# 13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed
# data.

# %%
print("Expected Frequencies Matrix:")
print(expected)
# Out:
# Expected Frequencies Matrix:
# [[40. 40.]
#  [30. 30.]]

# %% [markdown]
# 14.  Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

# %%
observed = np.array([50, 30, 20])
expected = np.array([40, 40, 20])

chi2_stat, p = stats.chisquare(observed, expected)
print(f"Chi-Square Statistic: {chi2_stat}, P-value: {p}")
# Out:
# Chi-Square Statistic: 5.0, P-value: 0.0820849986238988

# %% [markdown]
# 15. Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics.

# %%
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = stats.chi2.pdf(x, df=2)
plt.plot(x, y)
plt.title("Chi-Square Distribution")
plt.show()

# %% [markdown]
# 16. Implement an F-test using Python to compare the variances of two random samples.|

# %%
sample1 = np.random.normal(50, 10, 30)
sample2 = np.random.normal(50, 15, 30)

f_stat = np.var(sample1, ddof=1) / np.var(sample2, ddof=1)
p_value = 1 - stats.f.cdf(f_stat, len(sample1) - 1, len(sample2) - 1)

print(f"F-statistic: {f_stat}, P-value: {p_value}")
# Out:
# F-statistic: 0.3431371659922468, P-value: 0.9973799973202611

# %% [markdown]
# 17. Write a Python program to perform an ANOVA test to compare means between multiple groups and
# interpret the results.

# %%
group1 = np.random.normal(50, 10, 30)
group2 = np.random.normal(55, 10, 30)
group3 = np.random.normal(60, 10, 30)

f_stat, p_value = stats.f_oneway(group1, group2, group3)
print(f"ANOVA F-statistic: {f_stat}, P-value: {p_value}")
# Out:
# ANOVA F-statistic: 9.991327581270747, P-value: 0.00012415259300622321

# %% [markdown]
# 18. Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results.

# %%
import seaborn as sns

data = pd.DataFrame({'Score': np.concatenate([group1, group2, group3]),
                     'Group': ['G1'] * 30 + ['G2'] * 30 + ['G3'] * 30})

sns.boxplot(x='Group', y='Score', data=data)
plt.title("ANOVA Group Comparison")
plt.show()

# %% [markdown]
# 19. Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA.

# %%
from scipy.stats import shapiro, levene

# Normality check
for i, group in enumerate([group1, group2, group3]):
    stat, p = shapiro(group)
    print(f"Group {i+1} Normality P-value: {p}")

# Equal variance check
stat, p = levene(group1, group2, group3)
print(f"Levene's Test P-value: {p}")
# Out:
# Group 1 Normality P-value: 0.09942264550432761
# Group 2 Normality P-value: 0.7735629541847397
# Group 3 Normality P-value: 0.9026594417850767
# Levene's Test P-value: 0.07847072086587306

# %% [markdown]
# 20. Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the
# results.

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import pandas as pd
import numpy as np


data = pd.DataFrame({'Score': np.concatenate([group1, group2, group3]),
                     'Factor1': ['A'] * 45 + ['B'] * 45,  # Corrected Factor1 length
                     'Factor2': ['X'] * 30 + ['Y'] * 30 + ['Z'] * 30}) #Corrected Factor2 length to match others

model = ols('Score ~ C(Factor1) + C(Factor2) + C(Factor1):C(Factor2)', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
#                              sum_sq    df             F    PR(>F)
# C(Factor1)            -6.787341e-13   1.0 -6.790048e-15  1.000000
# C(Factor2)             3.749072e+02   2.0  1.875283e+00  0.174437
# C(Factor1):C(Factor2)  1.840621e+03   2.0  9.206775e+00  0.000238
# Residual               8.596573e+03  86.0           NaN       NaN
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 1
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# 21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing.

# %%
x = np.linspace(0, 5, 100)
y = stats.f.pdf(x, 5, 2)
plt.plot(x, y)
plt.title("F-Distribution")
plt.show()

# %% [markdown]
# 22. Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means.

# %%
n = 30
sample_variance = np.var(sample1, ddof=1)
pop_variance = 100

chi2_stat = (n - 1) * sample_variance / pop_variance
p_value = stats.chi2.sf(chi2_stat, df=n-1)

print(f"Chi-Square Test Statistic: {chi2_stat}, P-value: {p_value}")
# Out:
# Chi-Square Test Statistic: 19.84063810006368, P-value: 0.8978117955981985

# %% [markdown]
# 23. Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means.

# %%
from statsmodels.stats.proportion import proportions_ztest

success = np.array([50, 30])
samples = np.array([100, 100])

z_stat, p_value = proportions_ztest(success, samples)
print(f"Z-statistic: {z_stat}, P-value: {p_value}")
# Out:
# Z-statistic: 2.886751345948129, P-value: 0.003892417122778628

# %% [markdown]
# 24. Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results.

# %%
n = 30
sample_variance = np.var(sample1, ddof=1)
pop_variance = 100

chi2_stat = (n - 1) * sample_variance / pop_variance
p_value = stats.chi2.sf(chi2_stat, df=n-1)

print(f"Chi-Square Test Statistic: {chi2_stat}, P-value: {p_value}")
# Out:
# Chi-Square Test Statistic: 19.84063810006368, P-value: 0.8978117955981985

# %% [markdown]
# 25. Write a Python script to perform a Z-test for comparing proportions between two datasets or groups.

# %%
from statsmodels.stats.proportion import proportions_ztest

success = np.array([50, 30])
samples = np.array([100, 100])

z_stat, p_value = proportions_ztest(success, samples)
print(f"Z-statistic: {z_stat}, P-value: {p_value}")
# Out:
# Z-statistic: 2.886751345948129, P-value: 0.003892417122778628

# %% [markdown]
# 26. Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results.

# %%
f_stat, p_value = stats.levene(sample1, sample2)
print(f"F-Test Statistic: {f_stat}, P-value: {p_value}")
# Out:
# F-Test Statistic: 4.533493172319042, P-value: 0.0374944823196707

# %% [markdown]
# 27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results.

# %%
import numpy as np
import scipy.stats as stats

observed = np.random.randint(10, 50, 5)
expected = np.array([30, 30, 30, 30, 30])

# Scale 'expected' to match the sum of 'observed'
expected = expected * np.sum(observed) / np.sum(expected)

chi2_stat, p_value = stats.chisquare(observed, expected)
print(f"Chi-Square Statistic: {chi2_stat}, P-value: {p_value}")
# Out:
# Chi-Square Statistic: 12.342541436464089, P-value: 0.014977774866192648
